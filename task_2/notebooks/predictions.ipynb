# %%
# ---------------------------------------
# 1. Import Required Libraries
# ---------------------------------------
import pandas as pd
import numpy as np
import joblib

# %%
# ---------------------------------------
# 2. Load Saved Model and Feature Columns
# ---------------------------------------
model = joblib.load("../models/xgb_movie_rating_model.pkl")
feature_cols = joblib.load("../models/xgb_feature_columns.pkl")

print("✅ Model and feature list loaded successfully")
# Out:
# ✅ Model and feature list loaded successfully

# %%
# ---------------------------------------
# 3. Load New Data for Prediction
# ---------------------------------------
# NOTE: New data should have the SAME columns (excluding 'rating', 'votes')
new_data = pd.DataFrame(
    [
        {
            "name": "Example Movie",
            "year_int": 2022,
            "duration": 130.0,
            "genre": "Action,Adventure",  # 🔁 Changed pipe to comma
            "director": "Christopher Nolan",
            "actor 1": "Leonardo DiCaprio",
            "actor 2": "Tom Hardy",
            "actor 3": "Joseph Gordon-Levitt",
            "genre_split": ["Action", "Adventure"],  # 🔁 Changed to list
            "genre_count": 2,
            "director_avg_rating": 8.5,
            "actor_popularity": 8.9,
        }
    ]
)

# %%
# ---------------------------------------
# 4. Align Columns with Training Data
# ---------------------------------------
# Just to be safe — ensure all required columns are present
missing_cols = set(feature_cols) - set(new_data.columns)
if missing_cols:
    raise ValueError(f"❌ Missing columns in new data: {missing_cols}")

# Ensure correct column order
new_data = new_data[feature_cols]

# %%
# ---------------------------------------
# 5. Make Prediction
# ---------------------------------------
predicted_rating = model.predict(new_data)[0]
print(f"🎯 Predicted Movie Rating: {predicted_rating:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\irisDS\lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       1 # ---------------------------------------
# ...
